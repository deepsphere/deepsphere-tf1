# %% [markdown]
# /!\ set download to true to download SHREC17 in data_path directory
# will apply projection of all object from SHREC17 dataset to a unit sphere and augment dataset with random rotations

# %% [markdown]
# ## 0 Load packages

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from load_shrec import Shrec17DeepSphere as shrecSet
import healpy as hp
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (17, 5)

# %% [markdown]
# ## 1 load dataset

# %%
download = False
data_path = '../data/shrec17/'

# %%
train_dataset = shrecSet(data_path, 'train', nside=32, augmentation=5)
# Out:
# transform ../data/shrec17/train_perturbed/000032.obj...
# transform ../data/shrec17/train_perturbed/000032.obj...
# transform ../data/shrec17/train_perturbed/000032.obj...
# transform ../data/shrec17/train_perturbed/000032.obj...
# transform ../data/shrec17/train_perturbed/000032.obj...
# transform ../data/shrec17/train_perturbed/000033.obj...
# transform ../data/shrec17/train_perturbed/000033.obj...
# transform ../data/shrec17/train_perturbed/000033.obj...
# transform ../data/shrec17/train_perturbed/000033.obj...
# transform ../data/shrec17/train_perturbed/000033.obj...
# transform ../data/shrec17/train_perturbed/000034.obj...
# transform ../data/shrec17/train_perturbed/000034.obj...
# transform ../data/shrec17/train_perturbed/000034.obj...
# transform ../data/shrec17/train_perturbed/000034.obj...
# transform ../data/shrec17/train_perturbed/000034.obj...
# transform ../data/shrec17/train_perturbed/000035.obj...
# transform ../data/shrec17/train_perturbed/000035.obj...
# ...
